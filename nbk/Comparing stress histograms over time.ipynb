# %% [markdown]
# This notebook addresses one of Ernesto-the-besto's challenges: show him the time-evolution of the stress histograms.
#
# My plan is to generate two visuals: a collection stress histograms across all years, and a plot of total stress over time.
#
# In this notebook I use R=0.2 and no conditioning.

# %%
""" Importing the data!!! """
import pyreadstat as prs
raw_df, meta = prs.read_sas7bdat("../dat/gss7222_r3.sas7bdat")

# %%
""" Cleaning the data and setting the replicating core """
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../src')
from clean_data_1 import transform_dataframe_1
 
# Clean data 
df, metadata = transform_dataframe_1(raw_df)    

# Set variables of interest
variables = ["PARTYID","POLVIEWS","NATSPAC","NATENVIR","NATHEAL","NATCITY","NATCRIME","NATDRUG","NATEDUC","NATRACE","NATARMS",
"NATAID","NATFARE","NATROAD","NATSOC","NATMASS","NATPARK","NATCHLD","NATSCI","EQWLTH","SPKATH","COLATH","LIBATH","SPKRAC","COLRAC","LIBRAC","SPKCOM","COLCOM","LIBCOM","SPKMIL","COLMIL","LIBMIL","SPKHOMO",
"COLHOMO","LIBHOMO","SPKMSLM","COLMSLM","LIBMSLM","CAPPUN","GUNLAW","COURTS","GRASS","ATTEND","RELITEN","POSTLIFE","PRAYER","AFFRMACT","WRKWAYUP","HELPFUL",
"FAIR","TRUST","CONFINAN","CONBUS","CONCLERG","CONEDUC","CONFED","CONLABOR","CONPRESS","CONMEDIC","CONTV","CONJUDGE","CONSCI","CONLEGIS","CONARMY","GETAHEAD","FEPOL","ABDEFECT","ABNOMORE","ABHLTH","ABPOOR","ABRAPE","ABSINGLE","ABANY","SEXEDUC","DIVLAW","PREMARSX","TEENSEX","XMARSEX","HOMOSEX","PORNLAW",
"SPANKING","LETDIE1","SUICIDE1","SUICIDE2","POLHITOK","POLABUSE","POLMURDR","POLESCAP","POLATTAK","NEWS","TVHOURS","FECHLD","FEPRESCH","FEFAM","RACDIF1","RACDIF2","RACDIF3",
"RACDIF4","HELPPOOR","MARHOMO", "PRESLAST_NONCONFORM", "PRESLAST_DEMREP", "VOTELAST"]

# %%
from belief_to_stress_histogram import belief_to_stress_histogram
import os
import imageio


start_year = 1972
end_year = 2018
duration = 4

means = []
median = []
sums = []
mins = []
maxs = []

# Directory to save frames
frames_dir = "GIF_frames"
os.makedirs(frames_dir, exist_ok=True)

for i in range(start_year, end_year, 2):
    print(i)
    stress_vec, variable_list, stats = belief_to_stress_histogram(df, variables, i, duration, plot=True, density=True)
    means.append(stats['mean'])
    median.append(stats['median'])
    sums.append(stats['sum'])
    mins.append(stats['min'])
    maxs.append(stats['max'])

    # Display year as title
    # plt.title(f"Year: {i} - {i+duration}")

    # # Set x and y axes to be stable
    # plt.xlim(-40, 10)
    # plt.ylim(-0.01, 0.35)

    # plt.savefig(f"{frames_dir}/frame_{i}.png")
    # plt.close()


def create_gif(frames_dir, output_file="network_evolution.gif", fps=3):
    frames = []
    frame_files = sorted([f for f in os.listdir(frames_dir) if f.endswith(".png")])
    for frame_file in frame_files:
        frame_path = os.path.join(frames_dir, frame_file)
        frames.append(imageio.imread(frame_path))
    
    imageio.mimsave(output_file, frames, fps=fps)

# create_gif(frames_dir)
plt.legend(loc='upper left')
# Out:
# 1972
# c:\Users\timbo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\timbo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\timbo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\timbo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\timbo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
# ...

# %%
# Now we can go through the stats and plot the results
import matplotlib.pyplot as plt

plt.plot(range(start_year, end_year, 2), means, label='Mean')
plt.plot(range(start_year, end_year, 2), median, label='Median')
plt.plot(range(start_year, end_year, 2), mins, label='Min')
plt.plot(range(start_year, end_year, 2), maxs, label='Max')

plt.xlabel('Year')
plt.ylabel('Stress')
plt.title('Stress over time')
plt.legend()
plt.show()
