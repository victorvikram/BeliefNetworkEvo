# %% [markdown]
# ## qué bolá, mi gente 😼
#
# In this lesson, we will learn how to condition a network on a variable.
#
# In plain English, this means we will generate the belief network of all people who hold a certain belief (or lack thereof).
#
# First, we import and clean the data.

# %%
import os
import sys
project_root = os.path.dirname(os.path.dirname(os.path.abspath("..")))
if project_root not in sys.path:
    sys.path.append(project_root)
from CLEAN.datasets.import_gss import import_dataset
from CLEAN.datasets.clean_raw_data import clean_datasets
from CLEAN.source_code.generators.corr_make_network import calculate_correlation_matrix, CorrelationMethod, EdgeSuppressionMethod
from CLEAN.source_code.visualizers.network_visualizer import generate_html_visualization

# %%
df, _ = import_dataset()
cleaned_df = clean_datasets()
# print list of all vars
print(list(cleaned_df.columns))
# Out:
# Dataset loaded! 🐱✨           🐾🐱�
# Cached raw data to: c:\Users\timbo\Github\BeliefNetworkEvo\CLEAN\datasets\cached_data\gss_cache.pkl
# Loading from cache...
# Done! ✨
# ['ABDEFECT', 'HELPNOT', 'NATFAREY', 'RACDIF3', 'YEAR', 'HELPFUL', 'POLESCAP', 'AFFRMACT', 'HELPOTH', 'NATAID', 'TEENSEX', 'CONARMY', 'NATEDUCY', 'NATAIDY', 'SPKHOMO', 'POPULAR', 'POLMURDR', 'TRUST', 'SUICIDE2', 'CONCLERG', 'NATDRUGY', 'LIBMSLM', 'GETAHEAD', 'LIBHOMO', 'POSTLIFE', 'NATFARE', 'ABHLTH', 'NATHEAL', 'NATSPACY', 'MARHOMO', 'POLABUSE', 'CONEDUC', 'NATCRIME', 'ABRAPE', 'NATEDUC', 'FEPOL', 'HELPBLK', 'WORKHARD', 'COLCOM', 'NATCITY', 'SPKMSLM', 'COLMIL', 'COLMSLM', 'SPKMIL', 'COLRAC', 'CONBUS', 'EQWLTH', 'SUICIDE1', 'POLVIEWS', 'BALLOT', 'CONFED', 'SPKRAC', 'GRASS', 'FEPRESCH', 'FEFAM', 'CONTV', 'POLHITOK', 'NATENVIY', 'OBEY', 'HOMOSEX', 'SEXEDUC', 'NATSCI', 'WRKWAYUP', 'NATDRUG', 'NATMASS', 'HELPPOOR', 'NATPARK', 'ABANY', 'SPANKING', 'NATRACEY', 'THNKSELF', 'SPKCOM', 'XMARSEX', 'NATHEALY', 'FECHLD', 'ABNOMORE', 'CONLEGIS', 'CONJUDGE', 'CONFINAN', 'NATCHLD', 'CONPRESS', 'NATARMS', 'COLATH', 'NATRACE', 'PARTYID', 'ABPOOR', 'GUNLAW', 'NATENRGY', 'CONMEDIC', 'LIBMIL', 'SPKATH', 'ABSINGLE', 'PORNLAW', 'NATENVIR', 'NATCRIMY', 'LIBCOM', 'RACDIF4', 'PREMARSX', 'ID', 'CONSCI', 'NATCITYY', 'PRAYER', 'COLHOMO', 'NATARMSY', 'LIBATH', 'RACDIF2', 'FAIR', 'CONLABOR', 'NATSOC', 'NATSPAC', 'NATROAD', 'CAPPUN', 'RACDIF1', 'LIBRAC', 'DIVLAW', 'LETDIE1', 'COURTS', 'POLATTAK', 'PRESLAST_DEMREP', 'PRESLAST_NONCONFORM', 'WOULDVOTELAST_DEMREP', 'WOULDVOTELAST_NONCONFORM', 'DIDVOTELAST', 'RELIG_Protestant', 'RELIG_Catholic', 'RELIG_Jewish', 'RELIG_None', 'RELIG_Other', 'RELIG_Buddhism', 'RELIG_Hinduism', 'RELIG_Other_eastern_religions', 'RELIG_Muslim', 'RELIG_Orthodox_christian', 'RELIG_Christian', 'RELIG_Native_american', 'RELIG_Inter_nondenominational']

# %% [markdown]
# https://gssdataexplorer.norc.org/variables/vfilter
# and clean_raw_data.py

# %%
vars_to_condition = 'POLVIEWS'
years_of_interest = [2018, 2020, 2022]
# Value counts of this variable
cleaned_df[vars_to_condition].value_counts()
# Out:
# POLVIEWS
#  0.000000    23992
#  0.333333     9596
#  0.666667     9361
# -0.333333     7900
# -0.666667     7623
#  1.000000     2165
# -1.000000     2081
# Name: count, dtype: int64

# %%
import numpy as np
import pandas as pd

# --- Your existing helper functions ---

def binarize_dataframe(df, threshold=0.0):
    """
    Binarize a DataFrame based on a threshold.
    - If threshold == 0: Only exactly zero values are set to 0; all non-zero values are set to 1.
    - If threshold > 0: Values with absolute magnitude >= threshold are set to 1; others are set to 0.
    """
    if threshold == 0:
        return (df != 0).astype(int)
    else:
        return (np.abs(df) >= threshold).astype(int)

def align_dataframes(df1, df2):
    """
    Ensure df1 and df2 have the same columns and index, 
    filling missing values with zero.
    """
    all_columns = df1.columns.union(df2.columns)
    all_index = df1.index.union(df2.index)
    
    df1 = df1.reindex(index=all_index, columns=all_columns, fill_value=0)
    df2 = df2.reindex(index=all_index, columns=all_columns, fill_value=0)
    
    return df1, df2

def graph_edit_distance(df1, df2, threshold=0.0, undirected=True):
    """
    Compute the Graph Edit Distance (GED) between two DataFrames.
    
    Args:
        df1 (pd.DataFrame): First correlation matrix.
        df2 (pd.DataFrame): Second correlation matrix.
        threshold (float): Threshold for binarization. Default is 0.0.
        undirected (bool): Whether the graphs are undirected. Default is True.
    
    Returns:
        int: Graph Edit Distance (GED) as a single scalar value.
    """
    # Align DataFrames
    df1, df2 = align_dataframes(df1, df2)

    # Binarize the DataFrames
    bin_df1 = binarize_dataframe(df1, threshold)
    bin_df2 = binarize_dataframe(df2, threshold)

    # Compute the difference matrix and sum over all elements
    diff_matrix = np.abs(bin_df1 - bin_df2)
    ged = np.sum(diff_matrix.values)
    if undirected:
        ged = ged // 2  # For undirected graphs, each difference is counted twice
    
    return int(ged)

# --- The new function that runs the whole pipeline for each variable ---

def compute_and_save_ged(cleaned_df, variables, years_of_interest,
                         threshold=0.05,
                         output_file="ged_results.csv",
                         min_percent=0.05):
    """
    For each variable in `variables`, condition the cleaned DataFrame on >0 and <0,
    calculate the correlation matrices for each subset, compute the GED between these matrices,
    print the result, and save all GEDs to a CSV file.
    
    If one of the conditions has less than min_percent of the total records,
    the variable is skipped.
    
    Parameters:
        cleaned_df (pd.DataFrame): The pre-cleaned dataframe.
        variables (list): List of variable names (as strings) on which to condition the dataframe.
        years_of_interest (list): List of years to pass to the correlation matrix function.
        threshold (float): Threshold for binarization in GED computation.
        output_file (str): The file name to which the GED results will be saved.
        min_percent (float): Minimum percentage (as a decimal) of total records required for both conditions.
    
    Returns:
        dict: A dictionary mapping each variable to its computed GED.
    """
    # Make a copy so that we don't alter the original dataframe
    cleaned_df = cleaned_df.copy()

    # To store GED for each variable
    ged_results = {}
    total_records = len(cleaned_df)

    for var in variables:
        # Check if the variable is in the DataFrame
        if var not in cleaned_df.columns:
            print(f"Variable '{var}' not found in dataframe. Skipping.")
            continue
        
        # --- Condition on the variable ---
        # For values > 0:
        conditioned_df_positive = cleaned_df[cleaned_df[var] > 0]
        # For values < 0:
        conditioned_df_negative = cleaned_df[cleaned_df[var] < 0]
        
        pos_count = len(conditioned_df_positive)
        neg_count = len(conditioned_df_negative)
        pos_percent = pos_count / total_records
        neg_percent = neg_count / total_records
        
        # Print data completion stats
        print(f"Variable '{var}': {pos_count} records > 0 ({pos_percent:.1%}), "
              f"{neg_count} records < 0 ({neg_percent:.1%}).")
        
        # Check if either condition has less than the minimum percent of records
        if pos_percent < min_percent or neg_percent < min_percent:
            print(f"Skipping variable '{var}' due to low sample size in one of the conditions "
                  f"(min required: {min_percent:.1%}).")
            continue
        
        # --- Calculate correlation matrices ---
        # Note: `calculate_correlation_matrix`, `CorrelationMethod`, and 
        #       `EdgeSuppressionMethod` are assumed to be defined elsewhere.
        corr_matrix_A = calculate_correlation_matrix(
            conditioned_df_positive, 
            years_of_interest=years_of_interest,
            method=CorrelationMethod.PEARSON, 
            partial=True, 
            edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
            suppression_params={'regularization': 0.2}
        )
        
        corr_matrix_B = calculate_correlation_matrix(
            conditioned_df_negative, 
            years_of_interest=years_of_interest,
            method=CorrelationMethod.PEARSON, 
            partial=True, 
            edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
            suppression_params={'regularization': 0.2}
        )
        
        # --- Compute GED ---
        ged = graph_edit_distance(corr_matrix_A, corr_matrix_B, threshold)
        print(f"Variable: {var} - Graph Edit Distance (threshold={threshold}): {ged}")
        ged_results[var] = ged

    # --- Save the GED results to a CSV file ---
    ged_df = pd.DataFrame(list(ged_results.items()), columns=["Variable", "GED"])
    ged_df.to_csv(output_file, index=False)
    print(f"GED results saved to {output_file}")
    
    return ged_results

# --- Example usage ---
# Suppose you have:
# cleaned_df: your pre-cleaned dataframe

variables = ['ABDEFECT', 'HELPNOT', 'NATFAREY', 'RACDIF3', 'HELPFUL', 'POLESCAP', 
             'AFFRMACT', 'HELPOTH', 'NATAID', 'TEENSEX', 'CONARMY', 'NATEDUCY', 'NATAIDY', 
             'SPKHOMO', 'POPULAR', 'POLMURDR', 'TRUST', 'SUICIDE2', 'CONCLERG', 'NATDRUGY', 
             'LIBMSLM', 'GETAHEAD', 'LIBHOMO', 'POSTLIFE', 'NATFARE', 'ABHLTH', 'NATHEAL', 
             'NATSPACY', 'MARHOMO', 'POLABUSE', 'CONEDUC', 'NATCRIME', 'ABRAPE', 'NATEDUC', 
             'FEPOL', 'HELPBLK', 'WORKHARD', 'COLCOM', 'NATCITY', 'SPKMSLM', 'COLMIL', 
             'COLMSLM', 'SPKMIL', 'COLRAC', 'CONBUS', 'EQWLTH', 'SUICIDE1', 'POLVIEWS', 
             'CONFED', 'SPKRAC', 'GRASS', 'FEPRESCH', 'FEFAM', 'CONTV', 'POLHITOK', 
             'NATENVIY', 'OBEY', 'HOMOSEX', 'SEXEDUC', 'NATSCI', 'WRKWAYUP', 'NATDRUG', 
             'NATMASS', 'HELPPOOR', 'NATPARK', 'ABANY', 'SPANKING', 'NATRACEY', 'THNKSELF', 
             'SPKCOM', 'XMARSEX', 'NATHEALY', 'FECHLD', 'ABNOMORE', 'CONLEGIS', 'CONJUDGE', 
             'CONFINAN', 'NATCHLD', 'CONPRESS', 'NATARMS', 'COLATH', 'NATRACE', 'PARTYID', 
             'ABPOOR', 'GUNLAW', 'NATENRGY', 'CONMEDIC', 'LIBMIL', 'SPKATH', 'ABSINGLE', 
             'PORNLAW', 'NATENVIR', 'NATCRIMY', 'LIBCOM', 'RACDIF4', 'PREMARSX',
             'CONSCI', 'NATCITYY', 'PRAYER', 'COLHOMO', 'NATARMSY', 'LIBATH', 'RACDIF2', 
             'FAIR', 'CONLABOR', 'NATSOC', 'NATSPAC', 'NATROAD', 'CAPPUN', 'RACDIF1', 
             'LIBRAC', 'DIVLAW', 'LETDIE1', 'COURTS', 'POLATTAK', 'PRESLAST_DEMREP', 
             'PRESLAST_NONCONFORM', 'WOULDVOTELAST_DEMREP', 'WOULDVOTELAST_NONCONFORM', 
             'DIDVOTELAST', 'RELIG_Protestant', 'RELIG_Catholic', 'RELIG_Jewish', 'RELIG_None', 
             'RELIG_Other', 'RELIG_Buddhism', 'RELIG_Hinduism', 'RELIG_Other_eastern_religions', 
             'RELIG_Muslim', 'RELIG_Orthodox_christian', 'RELIG_Christian', 
             'RELIG_Native_american', 'RELIG_Inter_nondenominational']


years_of_interest = range(2010, 2021)
threshold = 0.075  # minimum correlation to be considered "connected"

min_percent = 0.15  # For example, require at least 5% of total records in each condition

ged_dict = compute_and_save_ged(cleaned_df, variables, years_of_interest,
                                threshold=threshold, min_percent=min_percent)
# Out:
# Variable 'ABDEFECT': 37199 records > 0 (51.4%), 9509 records < 0 (13.1%).
# Skipping variable 'ABDEFECT' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'HELPNOT': 10673 records > 0 (14.7%), 11323 records < 0 (15.6%).
# Skipping variable 'HELPNOT' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATFAREY': 18029 records > 0 (24.9%), 2635 records < 0 (3.6%).
# Skipping variable 'NATFAREY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RACDIF3': 16584 records > 0 (22.9%), 16678 records < 0 (23.0%).
# Variable: RACDIF3 - Graph Edit Distance (threshold=0.075): 39
# Variable 'HELPFUL': 20466 records > 0 (28.3%), 18809 records < 0 (26.0%).
# Variable: HELPFUL - Graph Edit Distance (threshold=0.075): 47
# Variable 'POLESCAP': 30769 records > 0 (42.5%), 11223 records < 0 (15.5%).
# Variable: POLESCAP - Graph Edit Distance (threshold=0.075): 42
# Variable 'AFFRMACT': 4854 records > 0 (6.7%), 18947 records < 0 (26.2%).
# Skipping variable 'AFFRMACT' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'HELPOTH': 15197 records > 0 (21.0%), 5758 records < 0 (8.0%).
# Skipping variable 'HELPOTH' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATAID': 2741 records > 0 (3.8%), 26402 records < 0 (36.5%).
# Skipping variable 'NATAID' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'TEENSEX': 25957 records > 0 (35.9%), 5821 records < 0 (8.0%).
# Skipping variable 'TEENSEX' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONARMY': 20038 records > 0 (27.7%), 5665 records < 0 (7.8%).
# Skipping variable 'CONARMY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATEDUCY': 20300 records > 0 (28.0%), 1574 records < 0 (2.2%).
# Skipping variable 'NATEDUCY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATAIDY': 1944 records > 0 (2.7%), 18740 records < 0 (25.9%).
# Skipping variable 'NATAIDY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'SPKHOMO': 31198 records > 0 (43.1%), 8729 records < 0 (12.1%).
# Skipping variable 'SPKHOMO' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'POPULAR': 809 records > 0 (1.1%), 29858 records < 0 (41.2%).
# Skipping variable 'POPULAR' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'POLMURDR': 4760 records > 0 (6.6%), 38122 records < 0 (52.7%).
# Skipping variable 'POLMURDR' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'TRUST': 15690 records > 0 (21.7%), 24779 records < 0 (34.2%).
# Variable: TRUST - Graph Edit Distance (threshold=0.075): 44
# Variable 'SUICIDE2': 3437 records > 0 (4.7%), 33631 records < 0 (46.5%).
# Skipping variable 'SUICIDE2' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONCLERG': 12411 records > 0 (17.1%), 10744 records < 0 (14.8%).
# Skipping variable 'CONCLERG' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATDRUGY': 15059 records > 0 (20.8%), 2882 records < 0 (4.0%).
# Skipping variable 'NATDRUGY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'LIBMSLM': 5603 records > 0 (7.7%), 5817 records < 0 (8.0%).
# Skipping variable 'LIBMSLM' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'GETAHEAD': 27376 records > 0 (37.8%), 4832 records < 0 (6.7%).
# Skipping variable 'GETAHEAD' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'LIBHOMO': 12247 records > 0 (16.9%), 27639 records < 0 (38.2%).
# Variable: LIBHOMO - Graph Edit Distance (threshold=0.075): 65
# Variable 'POSTLIFE': 35337 records > 0 (48.8%), 8811 records < 0 (12.2%).
# Skipping variable 'POSTLIFE' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATFARE': 8569 records > 0 (11.8%), 18163 records < 0 (25.1%).
# Skipping variable 'NATFARE' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'ABHLTH': 42101 records > 0 (58.2%), 4832 records < 0 (6.7%).
# Skipping variable 'ABHLTH' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATHEAL': 26314 records > 0 (36.4%), 2614 records < 0 (3.6%).
# Skipping variable 'NATHEAL' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATSPACY': 4235 records > 0 (5.9%), 9946 records < 0 (13.7%).
# Skipping variable 'NATSPACY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'MARHOMO': 3824 records > 0 (5.3%), 2534 records < 0 (3.5%).
# Skipping variable 'MARHOMO' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'POLABUSE': 4438 records > 0 (6.1%), 36044 records < 0 (49.8%).
# Skipping variable 'POLABUSE' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONEDUC': 13856 records > 0 (19.1%), 7314 records < 0 (10.1%).
# Skipping variable 'CONEDUC' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATCRIME': 26474 records > 0 (36.6%), 2486 records < 0 (3.4%).
# Skipping variable 'NATCRIME' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'ABRAPE': 37939 records > 0 (52.4%), 8552 records < 0 (11.8%).
# Skipping variable 'ABRAPE' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATEDUC': 26183 records > 0 (36.2%), 2761 records < 0 (3.8%).
# Skipping variable 'NATEDUC' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'FEPOL': 9982 records > 0 (13.8%), 25715 records < 0 (35.5%).
# Skipping variable 'FEPOL' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'HELPBLK': 8230 records > 0 (11.4%), 17983 records < 0 (24.8%).
# Skipping variable 'HELPBLK' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'WORKHARD': 17579 records > 0 (24.3%), 4058 records < 0 (5.6%).
# Skipping variable 'WORKHARD' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'COLCOM': 18323 records > 0 (25.3%), 22926 records < 0 (31.7%).
# Variable: COLCOM - Graph Edit Distance (threshold=0.075): 40
# Variable 'NATCITY': 18654 records > 0 (25.8%), 5796 records < 0 (8.0%).
# Skipping variable 'NATCITY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'SPKMSLM': 5121 records > 0 (7.1%), 6297 records < 0 (8.7%).
# Skipping variable 'SPKMSLM' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'COLMIL': 18444 records > 0 (25.5%), 19498 records < 0 (26.9%).
# Variable: COLMIL - Graph Edit Distance (threshold=0.075): 52
# Variable 'COLMSLM': 4544 records > 0 (6.3%), 9295 records < 0 (12.8%).
# Skipping variable 'COLMSLM' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'SPKMIL': 23564 records > 0 (32.6%), 13681 records < 0 (18.9%).
# Variable: SPKMIL - Graph Edit Distance (threshold=0.075): 49
# Variable 'COLRAC': 17859 records > 0 (24.7%), 22520 records < 0 (31.1%).
# Variable: COLRAC - Graph Edit Distance (threshold=0.075): 44
# Variable 'CONBUS': 10672 records > 0 (14.7%), 7579 records < 0 (10.5%).
# Skipping variable 'CONBUS' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'EQWLTH': 12814 records > 0 (17.7%), 18630 records < 0 (25.7%).
# Variable: EQWLTH - Graph Edit Distance (threshold=0.075): 49
# Variable 'SUICIDE1': 20771 records > 0 (28.7%), 15351 records < 0 (21.2%).
# Variable: SUICIDE1 - Graph Edit Distance (threshold=0.075): 38
# Variable 'POLVIEWS': 21122 records > 0 (29.2%), 17604 records < 0 (24.3%).
# Variable: POLVIEWS - Graph Edit Distance (threshold=0.075): 76
# Variable 'CONFED': 7517 records > 0 (10.4%), 16340 records < 0 (22.6%).
# Skipping variable 'CONFED' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'SPKRAC': 23221 records > 0 (32.1%), 15205 records < 0 (21.0%).
# Variable: SPKRAC - Graph Edit Distance (threshold=0.075): 35
# Variable 'GRASS': 12672 records > 0 (17.5%), 25997 records < 0 (35.9%).
# Variable: GRASS - Graph Edit Distance (threshold=0.075): 45
# Variable 'FEPRESCH': 14071 records > 0 (19.4%), 21034 records < 0 (29.1%).
# Variable: FEPRESCH - Graph Edit Distance (threshold=0.075): 44
# Variable 'FEFAM': 12649 records > 0 (17.5%), 22482 records < 0 (31.1%).
# Variable: FEFAM - Graph Edit Distance (threshold=0.075): 46
# Variable 'CONTV': 6070 records > 0 (8.4%), 16828 records < 0 (23.2%).
# Skipping variable 'CONTV' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'POLHITOK': 28259 records > 0 (39.0%), 11345 records < 0 (15.7%).
# Variable: POLHITOK - Graph Edit Distance (threshold=0.075): 47
# Variable 'NATENVIY': 17456 records > 0 (24.1%), 2324 records < 0 (3.2%).
# Skipping variable 'NATENVIY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'OBEY': 8668 records > 0 (12.0%), 18098 records < 0 (25.0%).
# Skipping variable 'OBEY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'HOMOSEX': 26756 records > 0 (37.0%), 15763 records < 0 (21.8%).
# Variable: HOMOSEX - Graph Edit Distance (threshold=0.075): 47
# Variable 'SEXEDUC': 35639 records > 0 (49.2%), 5127 records < 0 (7.1%).
# Skipping variable 'SEXEDUC' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATSCI': 10851 records > 0 (15.0%), 2861 records < 0 (4.0%).
# Skipping variable 'NATSCI' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'WRKWAYUP': 16111 records > 0 (22.3%), 4967 records < 0 (6.9%).
# Skipping variable 'WRKWAYUP' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATDRUG': 24442 records > 0 (33.8%), 3318 records < 0 (4.6%).
# Skipping variable 'NATDRUG' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATMASS': 19696 records > 0 (27.2%), 5005 records < 0 (6.9%).
# Skipping variable 'NATMASS' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'HELPPOOR': 11819 records > 0 (16.3%), 9331 records < 0 (12.9%).
# Skipping variable 'HELPPOOR' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATPARK': 17891 records > 0 (24.7%), 3120 records < 0 (4.3%).
# Skipping variable 'NATPARK' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'ABANY': 16652 records > 0 (23.0%), 22606 records < 0 (31.2%).
# Variable: ABANY - Graph Edit Distance (threshold=0.075): 39
# Variable 'SPANKING': 22354 records > 0 (30.9%), 9461 records < 0 (13.1%).
# Skipping variable 'SPANKING' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATRACEY': 8328 records > 0 (11.5%), 5622 records < 0 (7.8%).
# Skipping variable 'NATRACEY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'THNKSELF': 21369 records > 0 (29.5%), 5848 records < 0 (8.1%).
# Skipping variable 'THNKSELF' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'SPKCOM': 27550 records > 0 (38.1%), 15050 records < 0 (20.8%).
# Variable: SPKCOM - Graph Edit Distance (threshold=0.075): 56
# Variable 'XMARSEX': 39310 records > 0 (54.3%), 4767 records < 0 (6.6%).
# Skipping variable 'XMARSEX' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATHEALY': 18295 records > 0 (25.3%), 2871 records < 0 (4.0%).
# Skipping variable 'NATHEALY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'FECHLD': 24442 records > 0 (33.8%), 11008 records < 0 (15.2%).
# Variable: FECHLD - Graph Edit Distance (threshold=0.075): 38
# Variable 'ABNOMORE': 21187 records > 0 (29.3%), 25431 records < 0 (35.1%).
# Variable: ABNOMORE - Graph Edit Distance (threshold=0.075): 47
# Variable 'CONLEGIS': 5438 records > 0 (7.5%), 16386 records < 0 (22.6%).
# Skipping variable 'CONLEGIS' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONJUDGE': 14498 records > 0 (20.0%), 7933 records < 0 (11.0%).
# Skipping variable 'CONJUDGE' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONFINAN': 10700 records > 0 (14.8%), 9102 records < 0 (12.6%).
# Skipping variable 'CONFINAN' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATCHLD': 17757 records > 0 (24.5%), 2237 records < 0 (3.1%).
# Skipping variable 'NATCHLD' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONPRESS': 7132 records > 0 (9.9%), 16351 records < 0 (22.6%).
# Skipping variable 'CONPRESS' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATARMS': 9810 records > 0 (13.6%), 12581 records < 0 (17.4%).
# Skipping variable 'NATARMS' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'COLATH': 24941 records > 0 (34.5%), 19859 records < 0 (27.4%).
# Variable: COLATH - Graph Edit Distance (threshold=0.075): 46
# Variable 'NATRACE': 14102 records > 0 (19.5%), 7078 records < 0 (9.8%).
# Skipping variable 'NATRACE' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'PARTYID': 24329 records > 0 (33.6%), 34744 records < 0 (48.0%).
# Variable: PARTYID - Graph Edit Distance (threshold=0.075): 56
# Variable 'ABPOOR': 22295 records > 0 (30.8%), 24279 records < 0 (33.5%).
# Variable: ABPOOR - Graph Edit Distance (threshold=0.075): 50
# Variable 'GUNLAW': 36367 records > 0 (50.2%), 11940 records < 0 (16.5%).
# Variable: GUNLAW - Graph Edit Distance (threshold=0.075): 42
# Variable 'NATENRGY': 10895 records > 0 (15.1%), 1921 records < 0 (2.7%).
# Skipping variable 'NATENRGY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CONMEDIC': 21671 records > 0 (29.9%), 4522 records < 0 (6.2%).
# Skipping variable 'CONMEDIC' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'LIBMIL': 12612 records > 0 (17.4%), 24291 records < 0 (33.6%).
# Variable: LIBMIL - Graph Edit Distance (threshold=0.075): 54
# Variable 'SPKATH': 31400 records > 0 (43.4%), 11920 records < 0 (16.5%).
# Variable: SPKATH - Graph Edit Distance (threshold=0.075): 54
# Variable 'ABSINGLE': 20915 records > 0 (28.9%), 25663 records < 0 (35.5%).
# Variable: ABSINGLE - Graph Edit Distance (threshold=0.075): 39
# Variable 'PORNLAW': 16364 records > 0 (22.6%), 2153 records < 0 (3.0%).
# Skipping variable 'PORNLAW' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATENVIR': 24244 records > 0 (33.5%), 3515 records < 0 (4.9%).
# Skipping variable 'NATENVIR' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATCRIMY': 14510 records > 0 (20.0%), 2784 records < 0 (3.8%).
# Skipping variable 'NATCRIMY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'LIBCOM': 14262 records > 0 (19.7%), 27987 records < 0 (38.7%).
# Variable: LIBCOM - Graph Edit Distance (threshold=0.075): 58
# Variable 'RACDIF4': 15901 records > 0 (22.0%), 16643 records < 0 (23.0%).
# Variable: RACDIF4 - Graph Edit Distance (threshold=0.075): 39
# Variable 'PREMARSX': 14705 records > 0 (20.3%), 28877 records < 0 (39.9%).
# Variable: PREMARSX - Graph Edit Distance (threshold=0.075): 60
# Variable 'CONSCI': 19781 records > 0 (27.3%), 3434 records < 0 (4.7%).
# Skipping variable 'CONSCI' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATCITYY': 5665 records > 0 (7.8%), 8418 records < 0 (11.6%).
# Skipping variable 'NATCITYY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'PRAYER': 14190 records > 0 (19.6%), 20695 records < 0 (28.6%).
# Variable: PRAYER - Graph Edit Distance (threshold=0.075): 38
# Variable 'COLHOMO': 29483 records > 0 (40.7%), 11541 records < 0 (15.9%).
# Variable: COLHOMO - Graph Edit Distance (threshold=0.075): 71
# Variable 'NATARMSY': 6521 records > 0 (9.0%), 8680 records < 0 (12.0%).
# Skipping variable 'NATARMSY' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'LIBATH': 12899 records > 0 (17.8%), 29791 records < 0 (41.2%).
# Variable: LIBATH - Graph Edit Distance (threshold=0.075): 46
# Variable 'RACDIF2': 4086 records > 0 (5.6%), 29199 records < 0 (40.3%).
# Skipping variable 'RACDIF2' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'FAIR': 16008 records > 0 (22.1%), 23252 records < 0 (32.1%).
# Variable: FAIR - Graph Edit Distance (threshold=0.075): 39
# Variable 'CONLABOR': 5725 records > 0 (7.9%), 14400 records < 0 (19.9%).
# Skipping variable 'CONLABOR' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATSOC': 30366 records > 0 (41.9%), 3091 records < 0 (4.3%).
# Skipping variable 'NATSOC' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATSPAC': 5596 records > 0 (7.7%), 16518 records < 0 (22.8%).
# Skipping variable 'NATSPAC' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'NATROAD': 22734 records > 0 (31.4%), 5188 records < 0 (7.2%).
# Skipping variable 'NATROAD' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'CAPPUN': 42181 records > 0 (58.3%), 18666 records < 0 (25.8%).
# Variable: CAPPUN - Graph Edit Distance (threshold=0.075): 35
# Variable 'RACDIF1': 13846 records > 0 (19.1%), 18975 records < 0 (26.2%).
# Variable: RACDIF1 - Graph Edit Distance (threshold=0.075): 32
# Variable 'LIBRAC': 13462 records > 0 (18.6%), 24588 records < 0 (34.0%).
# Variable: LIBRAC - Graph Edit Distance (threshold=0.075): 42
# Variable 'DIVLAW': 11685 records > 0 (16.1%), 18524 records < 0 (25.6%).
# Variable: DIVLAW - Graph Edit Distance (threshold=0.075): 43
# Variable 'LETDIE1': 24339 records > 0 (33.6%), 11198 records < 0 (15.5%).
# Variable: LETDIE1 - Graph Edit Distance (threshold=0.075): 47
# Variable 'COURTS': 4569 records > 0 (6.3%), 43636 records < 0 (60.3%).
# Skipping variable 'COURTS' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'POLATTAK': 37047 records > 0 (51.2%), 3718 records < 0 (5.1%).
# Skipping variable 'POLATTAK' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'PRESLAST_DEMREP': 21663 records > 0 (29.9%), 23940 records < 0 (33.1%).
# Variable: PRESLAST_DEMREP - Graph Edit Distance (threshold=0.075): 52
# Variable 'PRESLAST_NONCONFORM': 2644 records > 0 (3.7%), 45385 records < 0 (62.7%).
# Skipping variable 'PRESLAST_NONCONFORM' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'WOULDVOTELAST_DEMREP': 8563 records > 0 (11.8%), 10935 records < 0 (15.1%).
# Skipping variable 'WOULDVOTELAST_DEMREP' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'WOULDVOTELAST_NONCONFORM': 3747 records > 0 (5.2%), 19189 records < 0 (26.5%).
# Skipping variable 'WOULDVOTELAST_NONCONFORM' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'DIDVOTELAST': 47652 records > 0 (65.8%), 19390 records < 0 (26.8%).
# Variable: DIDVOTELAST - Graph Edit Distance (threshold=0.075): 55
# Variable 'RELIG_Protestant': 40124 records > 0 (55.4%), 31829 records < 0 (44.0%).
# Variable: RELIG_Protestant - Graph Edit Distance (threshold=0.075): 35
# Variable 'RELIG_Catholic': 17242 records > 0 (23.8%), 54711 records < 0 (75.6%).
# Variable: RELIG_Catholic - Graph Edit Distance (threshold=0.075): 40
# Variable 'RELIG_Jewish': 1422 records > 0 (2.0%), 70531 records < 0 (97.4%).
# Skipping variable 'RELIG_Jewish' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_None': 9895 records > 0 (13.7%), 62058 records < 0 (85.7%).
# Skipping variable 'RELIG_None' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Other': 1224 records > 0 (1.7%), 70729 records < 0 (97.7%).
# Skipping variable 'RELIG_Other' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Buddhism': 272 records > 0 (0.4%), 71681 records < 0 (99.0%).
# Skipping variable 'RELIG_Buddhism' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Hinduism': 158 records > 0 (0.2%), 71795 records < 0 (99.2%).
# Skipping variable 'RELIG_Hinduism' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Other_eastern_religions': 44 records > 0 (0.1%), 71909 records < 0 (99.3%).
# Skipping variable 'RELIG_Other_eastern_religions' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Muslim': 201 records > 0 (0.3%), 71752 records < 0 (99.1%).
# Skipping variable 'RELIG_Muslim' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Orthodox_christian': 176 records > 0 (0.2%), 71777 records < 0 (99.2%).
# Skipping variable 'RELIG_Orthodox_christian' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Christian': 1000 records > 0 (1.4%), 70953 records < 0 (98.0%).
# Skipping variable 'RELIG_Christian' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Native_american': 36 records > 0 (0.0%), 71917 records < 0 (99.3%).
# Skipping variable 'RELIG_Native_american' due to low sample size in one of the conditions (min required: 15.0%).
# Variable 'RELIG_Inter_nondenominational': 159 records > 0 (0.2%), 71794 records < 0 (99.2%).
# Skipping variable 'RELIG_Inter_nondenominational' due to low sample size in one of the conditions (min required: 15.0%).
# GED results saved to ged_results.csv

# %%
# Suppose ged_dict is structured like:
# {'VAR1': 10, 'VAR2': 5, 'VAR3': 15, ...}

# Sort the dictionary items by GED value in descending order and take the top 5
top5 = sorted(ged_dict.items(), key=lambda x: x[1], reverse=True)[:10]

print("Top GED values:'")
for var, ged in top5:
    print(f"{var}: {ged}")
# Out:
# Top GED values:'
# POLVIEWS: 76
# COLHOMO: 71
# LIBHOMO: 65
# PREMARSX: 60
# LIBCOM: 58
# SPKCOM: 56
# PARTYID: 56
# DIDVOTELAST: 55
# LIBMIL: 54
# SPKATH: 54

# %%
var = top5[1][0]
print(var)

# --- Condition on the variable ---
# For values > 0:
conditioned_df_positive = cleaned_df[cleaned_df[var] > 0]
# For values < 0:
conditioned_df_negative = cleaned_df[cleaned_df[var] < 0]


corr_matrix_A = calculate_correlation_matrix(
    conditioned_df_positive, 
    years_of_interest=years_of_interest,
    method=CorrelationMethod.PEARSON, 
    partial=True, 
    edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
    suppression_params={'regularization': 0.2}
)

corr_matrix_B = calculate_correlation_matrix(
    conditioned_df_negative, 
    years_of_interest=years_of_interest,
    method=CorrelationMethod.PEARSON, 
    partial=True, 
    edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
    suppression_params={'regularization': 0.2}
)


generate_html_visualization(
    corr_matrix_A,
    highlight_nodes=['PARTYID'],
    output_path='delete_this_file_A.html'
)

generate_html_visualization(
    corr_matrix_B,
    highlight_nodes=['PARTYID'],
    output_path='delete_this_file_B.html'
)
# Out:
# COLHOMO
# Network visualization has been saved to c:\Users\timbo\Github\BeliefNetworkEvo\CLEAN\notebooks\tutorials\delete_this_file_A.html
# Network visualization has been saved to c:\Users\timbo\Github\BeliefNetworkEvo\CLEAN\notebooks\tutorials\delete_this_file_B.html
