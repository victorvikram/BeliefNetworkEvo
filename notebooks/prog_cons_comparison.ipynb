# %%
# In this nbk we'll study the difference between progressive and conservative belief networks.
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import numpy as np

# Set random seed for reproducibility
np.random.seed(42)

from src.loaders.import_gss import import_dataset
from src.loaders.clean_raw_data import clean_datasets
#df, _ = import_dataset()
cleaned_df = clean_datasets()

# %%
# First we want to identify a large set of nodes that recurr across the full timespan of the GSS. 
from src.generators.corr_make_network import calculate_correlation_matrix
from src.generators.corr_make_network import CorrelationMethod, EdgeSuppressionMethod

BN_dict = {}

for start_year in range(1960, 2020, 2):
    timeframe = list(range(start_year, start_year+4))
    print("Loading BN for years:",timeframe)

    corr_matrix = calculate_correlation_matrix(
        cleaned_df, 
        years_of_interest=timeframe,
        method=CorrelationMethod.SPEARMAN, 
        partial=True, 
        edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
        suppression_params={'regularization': 0.2},
        verbose=False
        )
    
    if corr_matrix is not None: 
        BN_dict[start_year] = corr_matrix
# Out:
# Loading BN for years: [1960, 1961, 1962, 1963]
# This df is all NaNs. Have you selected a valid year?
# Loading BN for years: [1962, 1963, 1964, 1965]
# This df is all NaNs. Have you selected a valid year?
# Loading BN for years: [1964, 1965, 1966, 1967]
# This df is all NaNs. Have you selected a valid year?
# Loading BN for years: [1966, 1967, 1968, 1969]
# This df is all NaNs. Have you selected a valid year?
# Loading BN for years: [1968, 1969, 1970, 1971]
# This df is all NaNs. Have you selected a valid year?
# Loading BN for years: [1970, 1971, 1972, 1973]
# Loading BN for years: [1972, 1973, 1974, 1975]
# Loading BN for years: [1974, 1975, 1976, 1977]
# Loading BN for years: [1976, 1977, 1978, 1979]
# Loading BN for years: [1978, 1979, 1980, 1981]
# Loading BN for years: [1980, 1981, 1982, 1983]
# Loading BN for years: [1982, 1983, 1984, 1985]
# Loading BN for years: [1984, 1985, 1986, 1987]
# Loading BN for years: [1986, 1987, 1988, 1989]
# Loading BN for years: [1988, 1989, 1990, 1991]
# Loading BN for years: [1990, 1991, 1992, 1993]
# Loading BN for years: [1992, 1993, 1994, 1995]
# Loading BN for years: [1994, 1995, 1996, 1997]
# Loading BN for years: [1996, 1997, 1998, 1999]
# Loading BN for years: [1998, 1999, 2000, 2001]
# Loading BN for years: [2000, 2001, 2002, 2003]
# Loading BN for years: [2002, 2003, 2004, 2005]
# Loading BN for years: [2004, 2005, 2006, 2007]
# Loading BN for years: [2006, 2007, 2008, 2009]
# Loading BN for years: [2008, 2009, 2010, 2011]
# Loading BN for years: [2010, 2011, 2012, 2013]
# Loading BN for years: [2012, 2013, 2014, 2015]
# Loading BN for years: [2014, 2015, 2016, 2017]
# Loading BN for years: [2016, 2017, 2018, 2019]
# Loading BN for years: [2018, 2019, 2020, 2021]

# %%
# Find the intersection of the variables in all BNs from a given start year
start_year = 1984
intersection = set(BN_dict[start_year].columns)

print(f"{len(intersection)} variables in {start_year}: {intersection}")

for year in BN_dict:
    if year < start_year:
        continue
    intersection = intersection.intersection(set(BN_dict[year].columns))
    print(f"The year {year} has {len(BN_dict[year].columns)} variables and shares {len(intersection)} variables with the previous year")

# Print final intersection size and variables
print(f"Final intersection size: {len(intersection)}")
print(f"Final intersection variables: {intersection}")
# Out:
# 102 variables in 1984: {'ABNOMORE', 'NATMASS', 'CONBUS', 'PRESLAST_NONCONFORM', 'RACDIF3', 'GUNLAW', 'PRESLAST_DEMREP', 'ABHLTH', 'NATEDUCY', 'RELIG_Jewish', 'COLHOMO', 'CONTV', 'NATDRUGY', 'RELIG_Other', 'FEPOL', 'ABRAPE', 'NATHEALY', 'SPKCOM', 'POLHITOK', 'TRUST', 'LIBATH', 'HELPPOOR', 'FECHLD', 'SUICIDE1', 'RELIG_Protestant', 'CAPPUN', 'PREMARSX', 'CONLABOR', 'SPKATH', 'RACDIF1', 'ABDEFECT', 'NATFAREY', 'RELIG_None', 'ABPOOR', 'RELIG_Catholic', 'CONARMY', 'FEPRESCH', 'LETDIE1', 'LIBMIL', 'NATROAD', 'NATSPACY', 'OBEY', 'CONSCI', 'COLATH', 'SPKMIL', 'HELPOTH', 'CONPRESS', 'NATRACEY', 'NATSOC', 'POPULAR', 'WOULDVOTELAST_DEMREP', 'NATENVIY', 'HELPFUL', 'SEXEDUC', 'NATAIDY', 'FEFAM', 'SPKHOMO', 'ABANY', 'COLRAC', 'CONLEGIS', 'SPKRAC', 'SUICIDE2', 'POLMURDR', 'HELPNOT', 'WOULDVOTELAST_NONCONFORM', 'CONCLERG', 'DIVLAW', 'WORKHARD', 'NATARMSY', 'THNKSELF', 'NATCRIMY', 'RACDIF4', 'HELPBLK', 'POLABUSE', 'HOMOSEX', 'CONEDUC', 'DIDVOTELAST', 'RACDIF2', 'COLMIL', 'COURTS', 'XMARSEX', 'CONFED', 'NATCITYY', 'GRASS', 'POLATTAK', 'PARTYID', 'LIBRAC', 'POSTLIFE', 'GETAHEAD', 'CONFINAN', 'FAIR', 'COLCOM', 'NATPARK', 'LIBHOMO', 'EQWLTH', 'CONJUDGE', 'CONMEDIC', 'ABSINGLE', 'LIBCOM', 'PORNLAW', 'POLVIEWS', 'POLESCAP'}
# The year 1984 has 102 variables and shares 102 variables with the previous year
# The year 1986 has 106 variables and shares 102 variables with the previous year
# The year 1988 has 106 variables and shares 102 variables with the previous year
# The year 1990 has 105 variables and shares 102 variables with the previous year
# The year 1992 has 107 variables and shares 102 variables with the previous year
# The year 1994 has 104 variables and shares 99 variables with the previous year
# The year 1996 has 115 variables and shares 99 variables with the previous year
# The year 1998 has 116 variables and shares 99 variables with the previous year
# The year 2000 has 115 variables and shares 88 variables with the previous year
# The year 2002 has 116 variables and shares 88 variables with the previous year
# The year 2004 has 116 variables and shares 88 variables with the previous year
# The year 2006 has 118 variables and shares 87 variables with the previous year
# The year 2008 has 120 variables and shares 87 variables with the previous year
# The year 2010 has 121 variables and shares 87 variables with the previous year
# The year 2012 has 121 variables and shares 87 variables with the previous year
# The year 2014 has 121 variables and shares 87 variables with the previous year
# The year 2016 has 121 variables and shares 87 variables with the previous year
# The year 2018 has 118 variables and shares 87 variables with the previous year
# Final intersection size: 87
# Final intersection variables: {'ABNOMORE', 'NATMASS', 'CONBUS', 'GUNLAW', 'RACDIF3', 'ABHLTH', 'RELIG_Jewish', 'COLHOMO', 'CONTV', 'RELIG_Other', 'FEPOL', 'ABRAPE', 'SPKCOM', 'POLHITOK', 'TRUST', 'LIBATH', 'HELPPOOR', 'FECHLD', 'SUICIDE1', 'RELIG_Protestant', 'CAPPUN', 'PREMARSX', 'CONLABOR', 'SPKATH', 'RACDIF1', 'ABDEFECT', 'RELIG_None', 'ABPOOR', 'RELIG_Catholic', 'CONARMY', 'FEPRESCH', 'LETDIE1', 'LIBMIL', 'NATROAD', 'OBEY', 'CONSCI', 'COLATH', 'SPKMIL', 'HELPOTH', 'CONPRESS', 'NATSOC', 'POPULAR', 'HELPFUL', 'SEXEDUC', 'FEFAM', 'SPKHOMO', 'ABANY', 'COLRAC', 'CONLEGIS', 'SPKRAC', 'SUICIDE2', 'POLMURDR', 'HELPNOT', 'WOULDVOTELAST_NONCONFORM', 'CONCLERG', 'WORKHARD', 'THNKSELF', 'RACDIF4', 'HELPBLK', 'POLABUSE', 'HOMOSEX', 'CONEDUC', 'DIDVOTELAST', 'RACDIF2', 'COLMIL', 'COURTS', 'XMARSEX', 'CONFED', 'GRASS', 'POLATTAK', 'PARTYID', 'LIBRAC', 'POSTLIFE', 'GETAHEAD', 'CONFINAN', 'FAIR', 'COLCOM', 'NATPARK', 'LIBHOMO', 'EQWLTH', 'CONJUDGE', 'CONMEDIC', 'ABSINGLE', 'LIBCOM', 'PORNLAW', 'POLVIEWS', 'POLESCAP'}

# %%
# The final intersection is the set of variables that are present in all BNs from 1984 to the present.
# They are:
recurring_variables_84 = ['PREMARSX', 'DIDVOTELAST', 'PORNLAW', 'LIBMIL', 'HELPBLK', 'SPKCOM', 'GRASS', 'LIBHOMO', 'COLRAC', 'XMARSEX', 
                          'RACDIF1', 'CAPPUN', 'RACDIF2', 'HELPPOOR', 'FEFAM', 'COLHOMO', 'LETDIE1', 'OBEY', 'CONCLERG', 'CONTV', 'SPKATH', 
                          'SUICIDE2', 'COLCOM', 'GUNLAW', 'LIBATH', 'FECHLD', 'HELPFUL', 'POSTLIFE', 'PARTYID', 'COLATH', 'RELIG_Jewish', 
                          'FAIR', 'HOMOSEX', 'CONLEGIS', 'COLMIL', 'CONEDUC', 'CONFINAN', 'POLABUSE', 'THNKSELF', 'FEPRESCH', 'POLATTAK', 
                          'CONBUS', 'CONMEDIC', 'WORKHARD', 'ABNOMORE', 'COURTS', 'ABDEFECT', 'ABPOOR', 'POLESCAP', 'HELPOTH', 'ABSINGLE', 
                          'RACDIF3', 'HELPNOT', 'POPULAR', 'NATSOC', 'LIBCOM', 'LIBRAC', 'SPKMIL', 'CONARMY', 'WOULDVOTELAST_NONCONFORM', 
                          'POLMURDR', 'CONJUDGE', 'GETAHEAD', 'ABANY', 'RACDIF4', 'ABRAPE', 'POLHITOK', 'SPKHOMO', 'CONLABOR', 'NATROAD', 
                          'ABHLTH', 'TRUST', 'RELIG_None', 'RELIG_Other', 'CONFED', 'FEPOL', 'POLVIEWS', 'NATPARK', 'RELIG_Protestant', 
                          'EQWLTH', 'CONPRESS', 'CONSCI', 'SUICIDE1', 'SEXEDUC', 'NATMASS', 'RELIG_Catholic', 'SPKRAC']
print("Number of recurring variables:", len(recurring_variables_84))
# Out:
# Number of recurring variables: 87

# %%
# We'll use these variables to create a clean temporal network from 1984 to 2020.

clean_BN_dict = {}

for start_year in range(1984, 2020, 2):
    timeframe = list(range(start_year, start_year+4))

    corr_matrix = calculate_correlation_matrix(
        cleaned_df, 
        years_of_interest=timeframe,
        variables_of_interest=recurring_variables_84,
        method=CorrelationMethod.SPEARMAN, 
        partial=True, 
        edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
        suppression_params={'regularization': 0.2},
        verbose=False
        )
    
    print(f"Loaded BN for years: {timeframe}. Num. of variables: {corr_matrix.shape[1]}")

    if corr_matrix is not None: 
        clean_BN_dict[start_year] = corr_matrix
# Out:
# Loaded BN for years: [1984, 1985, 1986, 1987]. Num. of variables: 87
# Loaded BN for years: [1986, 1987, 1988, 1989]. Num. of variables: 87
# Loaded BN for years: [1988, 1989, 1990, 1991]. Num. of variables: 87
# Loaded BN for years: [1990, 1991, 1992, 1993]. Num. of variables: 87
# Loaded BN for years: [1992, 1993, 1994, 1995]. Num. of variables: 87
# Loaded BN for years: [1994, 1995, 1996, 1997]. Num. of variables: 87
# Loaded BN for years: [1996, 1997, 1998, 1999]. Num. of variables: 87
# Loaded BN for years: [1998, 1999, 2000, 2001]. Num. of variables: 87
# Loaded BN for years: [2000, 2001, 2002, 2003]. Num. of variables: 87
# Loaded BN for years: [2002, 2003, 2004, 2005]. Num. of variables: 87
# Loaded BN for years: [2004, 2005, 2006, 2007]. Num. of variables: 87
# Loaded BN for years: [2006, 2007, 2008, 2009]. Num. of variables: 87
# Loaded BN for years: [2008, 2009, 2010, 2011]. Num. of variables: 87
# Loaded BN for years: [2010, 2011, 2012, 2013]. Num. of variables: 87
# Loaded BN for years: [2012, 2013, 2014, 2015]. Num. of variables: 87
# Loaded BN for years: [2014, 2015, 2016, 2017]. Num. of variables: 87
# Loaded BN for years: [2016, 2017, 2018, 2019]. Num. of variables: 87
# Loaded BN for years: [2018, 2019, 2020, 2021]. Num. of variables: 87

# %%
# We can visualize the temporal network as follows:
from src.visualizers.temporal_network_visualizer import generate_temporal_html_visualization
from src.generators.corr_make_network import calculate_correlation_matrix
from src.generators.corr_make_network import CorrelationMethod, EdgeSuppressionMethod
corr_mat_dict = generate_temporal_html_visualization(
    cleaned_df,
    nodes_to_highlight=['POLVIEWS'],
    time_window_length=4,
    start_year=1984,  # Changed from default
    end_year=2022,    # Changed from default
    step_size=2,
    method=CorrelationMethod.SPEARMAN,
    partial=True,
    edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
    suppression_params={'regularization': 0.2},
    output_path='temporal_network_1984_2020.html'
)
# Out:
# Is this shit on
# Temporal network visualization has been saved to temporal_network_1984_2020.html

# %%
# Now let's compare the progressive and conservative belief networks.

from src.generators.corr_make_conditioned_network import calculate_conditioned_correlation_matrix

var_to_condition = 'POLVIEWS' # think of self as liberal or conservative

liberal_BNs = {}
conservative_BNs = {}

for start_year in range(1984, 2020, 2):
    timeframe = list(range(start_year, start_year+4))

    liberal_corr_matrix = calculate_conditioned_correlation_matrix(
        cleaned_df, 
        years_of_interest=timeframe,
        variables_of_interest=recurring_variables_84,
        method=CorrelationMethod.SPEARMAN,
        partial=True,
        edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
        suppression_params={'regularization': 0.2},

        variable_to_condition=var_to_condition, 
        condition='less_than_zero', # for liberas
    )

    conservative_corr_matrix = calculate_conditioned_correlation_matrix(
        cleaned_df, 
        years_of_interest=timeframe,
        variables_of_interest=recurring_variables_84,
        method=CorrelationMethod.SPEARMAN,
        partial=True,
        edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
        suppression_params={'regularization': 0.2},

        variable_to_condition=var_to_condition, 
        condition='greater_than_zero', # for conservatives
    )

    if liberal_corr_matrix is not None:
        liberal_BNs[start_year] = liberal_corr_matrix
        nan_liberal = liberal_corr_matrix.isna().sum().sum()

    if conservative_corr_matrix is not None:
        conservative_BNs[start_year] = conservative_corr_matrix
        nan_conservative = conservative_corr_matrix.isna().sum().sum()

    # Print info about the matrices
    if liberal_corr_matrix is not None and conservative_corr_matrix is not None:
        num_vars_liberal = liberal_corr_matrix.shape[1] 
        num_vars_conservative = conservative_corr_matrix.shape[1]
        print(f"Loaded matrices for {start_year}, liberal = {num_vars_liberal}, conservative = {num_vars_conservative} vars.")
        #print(f"Number of NaN columns in liberal matrix: {nan_liberal}")
        #print(f"Number of NaN columns in conservative matrix: {nan_conservative}")
        
        if num_vars_liberal != num_vars_conservative:
            # Print the variables that are in one but not the other
            liberal_vars = set(liberal_corr_matrix.columns)
            conservative_vars = set(conservative_corr_matrix.columns)
            print(f"Variables in liberal but not conservative: {liberal_vars - conservative_vars}")
            print(f"Variables in conservative but not liberal: {conservative_vars - liberal_vars}")
# Out:
# Loaded matrices for 1984, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1986, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1988, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1990, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1992, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1994, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1996, liberal = 87, conservative = 87 vars.
# Loaded matrices for 1998, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2000, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2002, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2004, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2006, liberal = 87, conservative = 86 vars.
# Variables in liberal but not conservative: {'RELIG_Other'}
# Variables in conservative but not liberal: set()
# Loaded matrices for 2008, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2010, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2012, liberal = 87, conservative = 86 vars.
# Variables in liberal but not conservative: {'RELIG_Jewish'}
# Variables in conservative but not liberal: set()
# Loaded matrices for 2014, liberal = 87, conservative = 86 vars.
# Variables in liberal but not conservative: {'RELIG_Jewish'}
# Variables in conservative but not liberal: set()
# Loaded matrices for 2016, liberal = 87, conservative = 87 vars.
# Loaded matrices for 2018, liberal = 87, conservative = 87 vars.

# %%
# We can plot any of the networks as follows:
from src.visualizers.network_visualizer import generate_html_visualization

generate_html_visualization(
    liberal_BNs[2002], 
    output_path='liberal_2002.html',
)

generate_html_visualization(
    conservative_BNs[2002], 
    output_path='conservative_2002.html',
)
# Out:
# Network visualization has been saved to c:\Users\timbo\Github\BeliefNetworkEvo\CLEAN\notebooks\results\liberal_2002.html
# Network visualization has been saved to c:\Users\timbo\Github\BeliefNetworkEvo\CLEAN\notebooks\results\conservative_2002.html

# %%
# Now we can perform some comparisons between the two networks.
from src.analyzers.matrix_compare import compare_matrices, print_comparison_results

taxi_cab_distances = {}
euclidean_distances = {}
jaccard_similarities = {}
avg_degree_liberal = {}
avg_degree_conservative = {}
avg_degree_diffs = {}
avg_weight_sums_liberal = {}
avg_weight_sums_conservative = {}
avg_weight_sum_diffs = {}
avg_clustering_coefficient_liberal = {}
avg_clustering_coefficient_conservative = {}
avg_clustering_coefficient_diffs = {}
num_triangles_liberal = {}
num_triangles_conservative = {}
num_triangles_diffs = {}
spearman_correlations = {}
pearson_correlations = {}
spectral_gap_liberal = {}
spectral_gap_conservative = {}
delta_spectral_gap = {}
num_communities_liberal = {}
num_communities_conservative = {}
delta_num_communities = {}

for year in range(1984, 2020, 2):
    comparison_results = compare_matrices(
        liberal_BNs[year],
        conservative_BNs[year],
        triangle_threshold=0.01
        )
    #print(f"Year: {year}, Euclidean distance: {comparison_results['euclidean_distance']}")
    taxi_cab_distances[year] = comparison_results['taxi_cab_distance']
    euclidean_distances[year] = comparison_results['euclidean_distance']
    avg_degree_diffs[year] = comparison_results['delta_avg_degree']
    avg_degree_liberal[year] = comparison_results['avg_degree']['matrix1']
    avg_degree_conservative[year] = comparison_results['avg_degree']['matrix2']
    avg_weight_sums_liberal[year] = comparison_results['avg_weight_sum']['matrix1']
    avg_weight_sums_conservative[year] = comparison_results['avg_weight_sum']['matrix2']
    avg_weight_sum_diffs[year] = comparison_results['delta_avg_weight_sum']
    avg_clustering_coefficient_liberal[year] = comparison_results['clustering_coefficient']['matrix1']
    avg_clustering_coefficient_conservative[year] = comparison_results['clustering_coefficient']['matrix2']
    avg_clustering_coefficient_diffs[year] = comparison_results['delta_clustering_coefficient']
    num_triangles_liberal[year] = comparison_results['calc_num_triangles']['matrix1']
    num_triangles_conservative[year] = comparison_results['calc_num_triangles']['matrix2']
    num_triangles_diffs[year] = comparison_results['delta_num_triangles']
    spearman_correlations[year] = comparison_results['spearman_correlation']
    pearson_correlations[year] = comparison_results['pearson_correlation']
    spectral_gap_liberal[year] = comparison_results['spectral_gap']['matrix1']
    spectral_gap_conservative[year] = comparison_results['spectral_gap']['matrix2']
    delta_spectral_gap[year] = comparison_results['delta_spectral_gap']
    num_communities_liberal[year] = comparison_results['num_communities']['matrix1']
    num_communities_conservative[year] = comparison_results['num_communities']['matrix2']
    delta_num_communities[year] = comparison_results['delta_num_communities']

# Plot the euclidean distances
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(list(taxi_cab_distances.keys()), list(taxi_cab_distances.values()), marker='o')
plt.plot(list(euclidean_distances.keys()), list(euclidean_distances.values()), marker='o')
plt.legend(['Taxi-Cab Distance', 'Euclidean Distance'])
plt.xlabel('Year')
plt.ylabel('Distance')

plt.figure(figsize=(10, 6))
plt.plot(list(avg_degree_diffs.keys()), list(avg_degree_diffs.values()), marker='o')
plt.plot(list(avg_degree_liberal.keys()), list(avg_degree_liberal.values()), marker='o')
plt.plot(list(avg_degree_conservative.keys()), list(avg_degree_conservative.values()), marker='o')
plt.legend(['Avg. Degree Difference', 'Avg. Degree Liberal', 'Avg. Degree Conservative'])
plt.xlabel('Year')
plt.ylabel('Average Degree Difference')

plt.figure(figsize=(10, 6))
plt.plot(list(avg_weight_sum_diffs.keys()), list(avg_weight_sum_diffs.values()), marker='o')
plt.plot(list(avg_weight_sums_liberal.keys()), list(avg_weight_sums_liberal.values()), marker='o')
plt.plot(list(avg_weight_sums_conservative.keys()), list(avg_weight_sums_conservative.values()), marker='o')
plt.legend(['Avg. Weight Sum Difference', 'Avg. Weight Sum Liberal', 'Avg. Weight Sum Conservative'])
plt.xlabel('Year')
plt.ylabel('Average Weight Sum Difference')

plt.figure(figsize=(10, 6))
plt.plot(list(avg_clustering_coefficient_diffs.keys()), list(avg_clustering_coefficient_diffs.values()), marker='o')
plt.plot(list(avg_clustering_coefficient_liberal.keys()), list(avg_clustering_coefficient_liberal.values()), marker='o')
plt.plot(list(avg_clustering_coefficient_conservative.keys()), list(avg_clustering_coefficient_conservative.values()), marker='o')
plt.legend(['Avg. Clustering Coefficient Difference', 'Avg. Clustering Coefficient Liberal', 'Avg. Clustering Coefficient Conservative'])
plt.xlabel('Year')
plt.ylabel('Average Clustering Coefficient Difference')

plt.figure(figsize=(10, 6))
plt.plot(list(num_triangles_liberal.keys()), list(num_triangles_liberal.values()), marker='o')
plt.plot(list(num_triangles_conservative.keys()), list(num_triangles_conservative.values()), marker='o')
plt.plot(list(num_triangles_diffs.keys()), list(num_triangles_diffs.values()), marker='o')
plt.legend(['Num. Triangles Liberal', 'Num. Triangles Conservative', 'Delta Num. Triangles'])
plt.xlabel('Year')
plt.ylabel('Number of Triangles')

plt.figure(figsize=(10, 6))
plt.plot(list(pearson_correlations.keys()), list(pearson_correlations.values()), marker='o')
plt.legend(['Spearman Correlation', 'Pearson Correlation'])
plt.xlabel('Year')
plt.ylabel('Correlation')

plt.figure(figsize=(10, 6))
plt.plot(list(spectral_gap_liberal.keys()), list(spectral_gap_liberal.values()), marker='o')
plt.plot(list(spectral_gap_conservative.keys()), list(spectral_gap_conservative.values()), marker='o')
plt.plot(list(delta_spectral_gap.keys()), list(delta_spectral_gap.values()), marker='o')
plt.legend(['Spectral Gap Liberal', 'Spectral Gap Conservative'])
plt.xlabel('Year')
plt.ylabel('Spectral Gap')

plt.figure(figsize=(10, 6))
plt.plot(list(num_communities_liberal.keys()), list(num_communities_liberal.values()), marker='o')
plt.plot(list(num_communities_conservative.keys()), list(num_communities_conservative.values()), marker='o')
plt.plot(list(delta_num_communities.keys()), list(delta_num_communities.values()), marker='o')
plt.legend(['Num. Communities Liberal', 'Num. Communities Conservative', 'Delta Num. Communities'])
plt.xlabel('Year')
plt.ylabel('Number of Communities (Louvain method, out of the box networkx)')

# %%
# What is happening in 2000????
# First, let's make sure it's not random shit. 
# We are gonna do some bootstrapping to check if spike in 2000 is significant!
import pandas as pd
import multiprocessing as mp
from src.loaders.clean_raw_data import clean_datasets
from src.generators.corr_make_network import calculate_correlation_matrix
from src.generators.corr_make_network import CorrelationMethod, EdgeSuppressionMethod

recurring_variables_84 = ['PREMARSX', 'DIDVOTELAST', 'PORNLAW', 'LIBMIL', 'HELPBLK', 'SPKCOM', 'GRASS', 'LIBHOMO', 'COLRAC', 'XMARSEX', 
                          'RACDIF1', 'CAPPUN', 'RACDIF2', 'HELPPOOR', 'FEFAM', 'COLHOMO', 'LETDIE1', 'OBEY', 'CONCLERG', 'CONTV', 'SPKATH', 
                          'SUICIDE2', 'COLCOM', 'GUNLAW', 'LIBATH', 'FECHLD', 'HELPFUL', 'POSTLIFE', 'PARTYID', 'COLATH', 'RELIG_Jewish', 
                          'FAIR', 'HOMOSEX', 'CONLEGIS', 'COLMIL', 'CONEDUC', 'CONFINAN', 'POLABUSE', 'THNKSELF', 'FEPRESCH', 'POLATTAK', 
                          'CONBUS', 'CONMEDIC', 'WORKHARD', 'ABNOMORE', 'COURTS', 'ABDEFECT', 'ABPOOR', 'POLESCAP', 'HELPOTH', 'ABSINGLE', 
                          'RACDIF3', 'HELPNOT', 'POPULAR', 'NATSOC', 'LIBCOM', 'LIBRAC', 'SPKMIL', 'CONARMY', 'WOULDVOTELAST_NONCONFORM', 
                          'POLMURDR', 'CONJUDGE', 'GETAHEAD', 'ABANY', 'RACDIF4', 'ABRAPE', 'POLHITOK', 'SPKHOMO', 'CONLABOR', 'NATROAD', 
                          'ABHLTH', 'TRUST', 'RELIG_None', 'RELIG_Other', 'CONFED', 'FEPOL', 'POLVIEWS', 'NATPARK', 'RELIG_Protestant', 
                          'EQWLTH', 'CONPRESS', 'CONSCI', 'SUICIDE1', 'SEXEDUC', 'NATMASS', 'RELIG_Catholic', 'SPKRAC']

N_BOOTSTRAPS = 10
var_to_condition = 'POLVIEWS'

def run_bootstrap_analysis():
    df = clean_datasets()
    results = []
    failed_runs = []
    
    liberals = df[df[var_to_condition] < 0]
    conservatives = df[df[var_to_condition] > 0]

    # First add the non-bootstrapped version as sample_id 0
    for year in range(1984, 2020, 2):
        timeframe = list(range(year, year + 4))
        
        # Generate liberal correlation matrix (non-bootstrapped)
        liberal_corr_matrix = calculate_correlation_matrix(
            liberals, 
            years_of_interest=timeframe,
            variables_of_interest=recurring_variables_84,
            method=CorrelationMethod.SPEARMAN,
            partial=True,
            edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
            suppression_params={'regularization': 0.2},
            verbose=False
        )
        
        # Generate conservative correlation matrix (non-bootstrapped)
        conservative_corr_matrix = calculate_correlation_matrix(
            conservatives, 
            years_of_interest=timeframe,
            variables_of_interest=recurring_variables_84,
            method=CorrelationMethod.SPEARMAN,
            partial=True,
            edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
            suppression_params={'regularization': 0.2},
            verbose=False
        )
        
        if liberal_corr_matrix is not None and conservative_corr_matrix is not None:
            results.append({
                'year': year,
                'sample_id': 0,  # Non-bootstrapped version
                'liberal_correlation_matrix': liberal_corr_matrix,
                'conservative_correlation_matrix': conservative_corr_matrix
            })

    # Then add the bootstrapped versions starting from sample_id 1
    for sample_id in range(1, N_BOOTSTRAPS + 1):
        print(f"Bootstrapping: {sample_id}/{N_BOOTSTRAPS}")
        # Create bootstrap samples
        liberal_bootstrap = liberals.sample(n=len(liberals), replace=True)
        conservative_bootstrap = conservatives.sample(n=len(conservatives), replace=True)

        for year in range(1984, 2020, 2):
            timeframe = list(range(year, year + 4))
            # Generate liberal correlation matrix
            liberal_corr_matrix, liberal_sample_sizes = calculate_correlation_matrix(
                liberal_bootstrap, 
                years_of_interest=timeframe,
                variables_of_interest=recurring_variables_84,
                method=CorrelationMethod.SPEARMAN,
                partial=True,
                edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
                suppression_params={'regularization': 0.2},
                return_sample_sizes=True,
                verbose=False
            )
            
            # Generate conservative correlation matrix
            conservative_corr_matrix, conservative_sample_sizes = calculate_correlation_matrix(
                conservative_bootstrap, 
                years_of_interest=timeframe,
                variables_of_interest=recurring_variables_84,
                method=CorrelationMethod.SPEARMAN,
                partial=True,
                edge_suppression=EdgeSuppressionMethod.REGULARIZATION,
                suppression_params={'regularization': 0.2},
                return_sample_sizes=True,
                verbose=False
            )
            
            if liberal_corr_matrix is None or conservative_corr_matrix is None:
                print(f"Liberal correlation matrix is None for year {year} and sample_id {sample_id}") 
                failed_runs.append({'year': year, 'sample_id': sample_id, 'error': 'Liberal correlation matrix is None', 'liberal_sample_sizes': liberal_sample_sizes, 'conservative_sample_sizes': conservative_sample_sizes})
            
            if liberal_corr_matrix is not None and conservative_corr_matrix is not None:
                results.append({
                    'year': year,
                    'sample_id': sample_id,
                    'liberal_correlation_matrix': liberal_corr_matrix,
                    'conservative_correlation_matrix': conservative_corr_matrix
                })
    
    if results:
        pd.DataFrame(results).to_pickle('bootstrap_results_lib_cons.pkl')
        print(f"Saved original data plus {N_BOOTSTRAPS} bootstrap resamples, {len(results)} total belief networks (liberal and conservative)")
    else:
        print("No results generated")

run_bootstrap_analysis()
# Out:
# Loading dataset from from cache...
# Done! ✨
# Bootstrapping: 1/10
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002049279887071914
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00026816618810548005
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004734445016631018
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00031540483732805697
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004951202893751448
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002843203154694915
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00014638731545303202
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004698649883876116
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00019966477952835935
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.000495926487912064
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 8.546335715420933e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0006018201967588105
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.000113581648868513
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00017757218318755781
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.161784012397245e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00012132177196723443
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005142470691758042
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 3.77032963614963e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001750485486437813
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004993023454345851
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00016367722307681655
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00038576877604951933
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00012481376131023714
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00016686063442197276
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001782207351219022
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003269155967247144
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010401993812712567
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001395087709177427
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001705625905190896
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015257676683924632
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001024244659973578
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005013025885889814
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010250410451305612
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003472684774154832
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005179489306919062
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00011073245078441172
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 9.465490656768039e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.000574338718385288
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002530544150353873
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010980316221454916
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00017218311381475104
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.64010114859707e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0006734043375131537
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00047001152747606234
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004518263867425506
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00023677876421989412
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001681792744131958
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020815597398069743
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001425862027969099
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00011715774530778047
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004908570796638421
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001804937845302275
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00039314580351399375
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00031356388941700586
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005777037550718705
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 8.236427891414609e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 4.3225056214322165e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002548519112689297
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020566127551777607
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00023124946196535165
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 3.855129149443812e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020066190300721063
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00019333567018938578
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.629052693197217e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 4.68435759571744e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013433166012733922
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015386545767817278
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00011283324143992531
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002346020221222731
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003454992915907969
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00023971875610566268
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001356767273273031
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013142837101036872
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004410627150579827
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.000323385547358983
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013631546096618205
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002604794513050083
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005571697746964788
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002141144325496672
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0007065535671139394
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00031318752127232417
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004787086622431156
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00024612056774787563
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020194900677948066
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015222108792135267
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001470116806248699
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00024163966643373717
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# Failed to calculate partial correlations: The system is too ill-conditioned for this solver. The system is too ill-conditioned for this solver
# Liberal correlation matrix is None for year 2002 and sample_id 1
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005190589728002935
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00012396005021834158
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003940889114774355
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00023167702024939551
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00016569860001932945
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 8.420551334731793e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010333048197641386
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015387795982504983
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 9.76529160260974e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003970547564170107
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00031589069273333146
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00028688193595751267
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004090829321546943
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00018797699551711662
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00017617574526349557
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00034351502232142
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015688234709628537
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00035806911034341716
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 5.0029742367838106e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.000372063428692918
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00016699946913243256
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001432278415010909
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.887999441780235e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010877668871660594
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004352782668611221
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 3.3631652790647286e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020786690649154615
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004382107068671472
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013741699202153194
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003932813560767545
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00017551185333442346
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00014186227363567006
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 8.919422698672035e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002823410263120145
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020808230091639004
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00011903184280556811
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00014395972874220374
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00011437104130848095
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 7.031076150901578e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005130674068161893
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 8.973990402235359e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002990624338112832
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005172934937861419
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 9.778214128368375e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 9.402742699710968e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005764687343881468
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001887568275911796
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 9.71744319193475e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.983213559826748e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 5.802713790370887e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004006089112543456
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002923970656531569
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004244130207529887
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00014026557900732907
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.043967485361721e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00016112115232959674
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015428746008139526
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010509132173874632
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0004982446753191551
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002613423747405425
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003812050447957572
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00022785451335061545
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002703711288591961
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010587915930638953
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 7.221348126661045e-05
# ...
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001761786597887935
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.000334755905128492
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005336591687814109
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 7.233182389743726e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010956006950656207
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005513028761388816
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00024565692375398777
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00014795110116199762
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00016465733446092683
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 3.801054566618382e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003758812410189355
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013041404642250102
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00021764223253729496
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001671783957182782
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 7.56382714784446e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020596419435461587
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013579567227518235
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00012541226696423654
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0005094436323103327
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003372777783947615
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003523698604422988
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001718875459957246
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003774409644223448
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 5.575853886547705e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 6.608895523453856e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00022996907074586626
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00020072758401499358
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00024275978194597967
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 1.7448929639609924e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00011583611214259913
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00021283087080906202
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00010519123589691968
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 4.275858306100945e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00017426728272646055
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00022451384194700137
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001650700337934113
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0002898469913941081
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003581082335681206
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00022444928890474208
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00017353743756366144
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 7.467808545969079e-05
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00013281715209213476
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00034352566856624
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0001679367559797404
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00015073029145507922
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00029716615631809456
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00022752478644871133
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.0003636010302123936
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# c:\Users\timbo\miniconda3\envs\pythons_beliefs\lib\site-packages\sklearn\covariance\_graph_lasso.py:140: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: nan, tolerance: 0.00028140018090959623
#   coefs, _, _, _ = cd_fast.enet_coordinate_descent_gram(
# Failed to calculate partial correlations: The system is too ill-conditioned for this solver. The system is too ill-conditioned for this solver
# Liberal correlation matrix is None for year 2018 and sample_id 10
# Saved original data plus 10 bootstrap resamples, 179 total belief networks (liberal and conservative)

# %%
liberal_sample_sizes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 liberal_sample_sizes
#
# NameError: name 'liberal_sample_sizes' is not defined

# %%
# for liberal and conservative raw data, print the sample size timeseries
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

var_to_condition = 'POLVIEWS'
df = clean_datasets()
liberals = df[df[var_to_condition] < 0]
conservatives = df[df[var_to_condition] > 0]
# Out:
# Loading dataset from from cache...
# Done! ✨
